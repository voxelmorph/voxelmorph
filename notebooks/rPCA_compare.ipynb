# %% [markdown]
# # rPCA + Group Registration

# %%
import pandas as pd

file = '../results/MOLLI_post/group/rank_10_5_5/jointcorrelation/l2/image_loss_weight1/weight0.3/bspline/cps4_svfsteps7_svfscale1/e100/final_summary/results.csv'
df = pd.read_csv(file)
df
# Out:
#                        Cases       raw MSE  registered MSE   raw PCA  \
# 0   3355043_20140305_MOLLI_2  45448.358791    42545.171100  0.834689
# 1   1328081_20140129_MOLLI_1  28196.292173    27160.682920  0.815845
# 2   5179318_20131106_MOLLI_1  41157.030715    37885.274224  0.872763
# 3   5247547_20131120_MOLLI_3  40789.656297    38622.874213  0.816085
# 4   2550514_20140219_MOLLI_3  65985.645903    66330.399741  0.821557
# 5   2265167_20140212_MOLLI_2  33392.368340    31960.226076  0.810930
# 6   8185417_20140604_MOLLI_3   3383.828560     3159.192004  0.877476
# 7   2980827_20140416_MOLLI_2  41911.551882    40339.603615  0.871994
# 8   1351763_20131030_MOLLI_1  66388.752430    58241.078640  0.877501
# 9   5247547_20131120_MOLLI_2  43456.937765    41380.677481  0.829866
# 10  0387056_20140423_MOLLI_1   3323.744069     3082.916035  0.876835
#
#     registered PCA  raw T1err  registered T1err  MSE changes percentage  \
# ...

# %%
df.describe()
# Out:
#             raw MSE  registered MSE    raw PCA  registered PCA  raw T1err  \
# count     11.000000       11.000000  11.000000       11.000000  11.000000
# mean   37584.924266    37298.847343   0.845958        0.866707   5.277106
# std    20551.381860    20103.587052   0.028889        0.026193   2.125054
# min     3323.744069     3175.099073   0.810930        0.826661   2.950986
# 25%    30794.330256    32639.565755   0.818821        0.848904   3.688465
# 50%    41157.030715    39682.714485   0.834689        0.852707   4.842937
# 75%    44452.648278    43932.268177   0.874799        0.892280   6.338512
# max    66388.752430    67711.782701   0.877501        0.895658  10.234802
#
#        registered T1err  MSE changes percentage  PCA changes percentage  \
# count         11.000000               11.000000               11.000000
# mean           4.662451               -0.930469                2.467868
# std            1.746993                4.712168                0.889291
# ...

# %%
df2 = pd.read_csv('/Users/mona/Library/CloudStorage/OneDrive-Personal/Delft/thesis/progress/figs/wandb_export_2023-01-31T12_50_34.313+01_00.csv')
cases = list(df2['Cases'])
new_df = df[df['Cases'].isin(cases)]
new_df
# Out:
#                         Cases       raw MSE  registered MSE   raw PCA  \
# 0    8559809_20140402_MOLLI_3  31186.473174    29709.286562  0.854585
# 10   8286778_20131113_MOLLI_1  61133.286666    59169.552535  0.869069
# 20   5179318_20131106_MOLLI_2  45226.887148    43220.924349  0.864262
# 30   4143835_20140402_MOLLI_3  23368.286166    22216.946332  0.868674
# 40   4143835_20140402_MOLLI_2  29788.710066    28816.621648  0.855089
# 50   6157978_20140115_MOLLI_2  27494.197114    26243.266693  0.899037
# 60   7542042_20140528_MOLLI_1  28877.174396    26010.909560  0.812741
# 70   2980827_20140416_MOLLI_2  41911.551880    40431.098107  0.871994
# 80   4106618_20131009_MOLLI_2  17025.683539    16063.372244  0.858975
# 90   1328040_20131002_MOLLI_1  56300.966555    54859.927574  0.857066
# 100  8515597_20140611_MOLLI_3  35477.988766    34714.862325  0.804457
#
#      registered PCA  raw T1err  registered T1err  MSE changes percentage  \
# ...

# %%
new_df.describe()
# Out:
#             raw MSE  registered MSE    raw PCA  registered PCA  raw T1err  \
# count     11.000000       11.000000  11.000000       11.000000  11.000000
# mean   36162.836861    34677.887993   0.855995        0.871015   4.302588
# std    13668.549393    13491.911192   0.026549        0.021671   1.821224
# min    17025.683539    16063.372244   0.804457        0.824874   2.708822
# 25%    28185.685755    26127.088126   0.854837        0.865962   3.229581
# 50%    31186.473174    29709.286562   0.858975        0.870449   3.538415
# 75%    43569.219514    41826.011228   0.868871        0.880842   4.511791
# max    61133.286666    59169.552535   0.899037        0.911652   8.523048
#
#        registered T1err  MSE changes percentage  PCA changes percentage  \
# count         11.000000               11.000000               11.000000
# mean           3.737570               -4.449532                1.775523
# std            1.576115                2.106897                1.011082
# ...

# %%
import pickle
import numpy as np
filename = '/Users/mona/Documents/repo/voxelmorph-test/results/MOLLI_post/group/rank_10_5_5/jointcorrelation/l2/image_loss_weight1/weight0.3/bspline/cps4_svfsteps7_svfscale1/e100/final_summary/5247547_20131120_MOLLI_3_original_T1map.pickle'
with open(filename, 'rb') as handle:
    re = pickle.load(handle)
pmap = re['pmap']
sdmap = re['sdmap']
null_index = re['null_index']
S = re['S']
S_orig = S[None, None, :, :]
S_orig = S_orig.transpose(0, 1, 3, 2)
filename = '/Users/mona/Documents/repo/voxelmorph-test/results/MOLLI_post/group/rank_10_5_5/jointcorrelation/l2/image_loss_weight1/weight0.3/bspline/cps4_svfsteps7_svfscale1/e100/final_summary/5247547_20131120_MOLLI_3_register_T1map.pickle'
with open(filename, 'rb') as handle:
    re = pickle.load(handle)
pmap = re['pmap']
sdmap = re['sdmap']
null_index = re['null_index']
S = re['S']
S_regi = S[None, None, :, :]
S_regi = S_regi.transpose(0, 1, 3, 2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
title_font_size=8
title_pad = 10

fig = plt.figure(figsize=(6, 3))
ax1 = fig.add_subplot(1, 2, 1)
p1 = plt.imshow(np.squeeze(S_orig), cmap='jet')
plt.axis('off')
ax1.set_title(f"T1err_orig {np.mean(S_orig):.4f}", fontsize=title_font_size, pad=title_pad)
fig.colorbar(p1, ax=ax1)
ax2 = fig.add_subplot(1, 2, 2)
p2 = plt.imshow(np.squeeze(S_regi), cmap='jet')
plt.axis('off')
ax2.set_title(f"T1err_rigs {np.mean(S_regi):.4f}", fontsize=title_font_size, pad=title_pad)
fig.colorbar(p2, ax=ax2)
plt.subplots_adjust(left=0.0001, right=0.99, top=0.8,
                    bottom=0.1, wspace=0.001, hspace=0.2)
